# %%
import glob
import os.path as osp
import random
import numpy as np
import json
from PIL import Image
from tqdm import tqdm
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import torchvision
from torchvision import models, transforms
#torch.backends.cudnn.deterministic = True
#torch.backends.cudnn.benchmark = False

# %% [markdown]
# ### 乱数シード(共通)

# %%
# 乱数シード (共通)
torch.manual_seed(1234)
np.random.seed(1234)
random.seed(1234)

# %% [markdown]
# ### 前処理クラス

# %%
# 前処理クラス
class ImageTransform():

    def __init__(self, resize, mean, std):
        self.data_transform = {
            'train': transforms.Compose([
                transforms.RandomResizedCrop(resize, scale=(0.5, 1.0)),  # ランダムクロップ
                transforms.RandomHorizontalFlip(),                       # ランダムフリップ(水平)
                transforms.ToTensor(),                                   # Tensor変換
                transforms.Normalize(mean, std)                          # 標準化
            ]),
            'val': transforms.Compose([
                transforms.Resize(resize),                               # リサイズ
                transforms.CenterCrop(resize),                           # クロップ
                transforms.ToTensor(),                                   # Tensor変換
                transforms.Normalize(mean, std)                                   # 標準化
            ])
        }

    def __call__(self, img, phase='train'):
        return self.data_transform[phase](img)

# %% [markdown]
# ### データセットクラス

# %%
# アリとハチの画像データセットを作成
class HymenopteraDataset(data.Dataset):

    def __init__(self, file_list, transform=None, phase='train'):
        self.file_list = file_list
        self.transform = transform
        self.phase = phase


    def __len__(self):
        return len(self.file_list)


    def __getitem__(self, index):

        img_path = self.file_list[index]
        img = Image.open(img_path)

        img_transformed = self.transform(img, self.phase) # torch.Size([3, 224, 224])

        if self.phase == 'train':
            label = img_path[30:34]
        elif self.phase == 'val':
            label = img_path[28:32]

        if label == 'ants':
            label = 0
        elif label == 'bees':
            label = 1

        return img_transformed, label

# %% [markdown]
# ### ファイルパスリスト作成

# %%
# アリとハチの画像へのファイルパスのリストを作成する
def make_datapath_list(phase='train'):

    rootpath = "./data/Pytorch/hymenoptera_data/"
    target_path = osp.join(rootpath + phase + '/**/*.jpg')
    print(target_path)

    # ファイルパスを取得
    path_list = []
    for path in glob.glob(target_path):
        path_list.append(path)

    for i, path in enumerate(path_list):
        print(str(i) + ": " +  path)

    return path_list

# %% [markdown]
# ### データセット作成

# %%
# データセット作成
def makeDataset():

    # 訓練
    train_list = make_datapath_list(phase='train')

    # 検証
    val_list = make_datapath_list(phase='val')

    # データセット
    resize = 224
    mean = (0.485, 0.456, 0.406)
    std = (0.229, 0.224, 0.225)
    transform = ImageTransform(resize, mean, std)
    train_dataset = HymenopteraDataset(file_list=train_list, transform=transform, phase='train')
    val_dataset = HymenopteraDataset(file_list=val_list, transform=transform, phase='val')

    # 動作確認
    index = 0
    print(train_dataset.__getitem__(index)[0].size()) # img_transformed
    print(train_dataset.__getitem__(index)[1])        # label

    print("Training Data: ")
    for train_index in range(0, train_dataset.__len__()):
        print("train" + "_" + str(train_index) +  " :" + str(train_dataset.__getitem__(train_index)[1]))

    return train_dataset, val_dataset

# %% [markdown]
# ### データローダー

# %%
def dataLoader(train_dataset = None, val_dataset = None):
    
    # ミニバッチサイズ
    batch_size  = 32

    # DataLoader作成
    train_dataloader = torch.utils.data.DataLoader(
        train_dataset, batch_size = batch_size, shuffle = True
    )

    val_dataloader = torch.utils.data.DataLoader(
        val_dataset, batch_size = batch_size, shuffle = True
    )

    # 辞書にまとめる
    datasetloaders_dict = { 'train': train_dataloader, 'val': val_dataloader }

    # 動作確認
    batch_iterator = iter(datasetloaders_dict['train']) # イテレータに変換
    inputs, labels = next(batch_iterator) # 1番目の要素を取り出す
    print(inputs.size())
    print(labels)

    return datasetloaders_dict

# %% [markdown]
# ### トレーニングと検証

# %%
def train_model(net, dataloaders_dict, criterion, optimizer, num_epochs):
    
    # epochのループ
    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch+1, num_epochs))
        print('--------')

        # epochごとの学習と検証ループ
        for phase in ['train', 'val']:
            if phase == 'train':
                net.train() # 訓練モードのモデル
            else:
                net.eval()  # 検証モードのモデル

            epoch_loss = 0.0   # epochの損失和
            epoch_corrects = 0 # epochの正解数 

            # 未学習時の検証性能を確かめるため、epoch=0の訓練では未学習のモデルを使用する
            if (epoch == 0) and (phase == 'train'):
                continue

            # データローダからミニバッチを取り出すループ
            for inputs, labels in tqdm(dataloaders_dict[phase]):

                # optimzerを初期化
                optimizer.zero_grad()

                # forward計算
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = net(inputs)              # 出力
                    loss = criterion(outputs, labels)  # 誤差
                    _, preds = torch.max(outputs, 1)   # 予測ラベル

                    # 訓練時はbackpropagation
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                    # イテレーションの計算結果
                    # lossの合計を更新
                    epoch_loss += loss.item() * inputs.size(0) # 平均loss * バッチ数
                    # 正解数の合計を更新
                    epoch_corrects += torch.sum(preds == labels.data)

            # epochごとのlossと正解率を表示
            epoch_loss = epoch_loss / len(dataloaders_dict[phase].dataset)
            epoch_acc = epoch_corrects.double() / len(dataloaders_dict[phase].dataset)

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_acc))

# %% [markdown]
# # ベタにファインチューニングプログラムを書く

# %%
# データセット
train_dataset, val_dataset = makeDataset()

# データローダー
dataloaders_dict = dataLoader(train_dataset=train_dataset, val_dataset=val_dataset)
# Out:
# ./data/Pytorch/hymenoptera_data/train/**/*.jpg
# 0: ./data/Pytorch/hymenoptera_data/train/bees/2638074627_6b3ae746a0.jpg
# 1: ./data/Pytorch/hymenoptera_data/train/bees/507288830_f46e8d4cb2.jpg
# 2: ./data/Pytorch/hymenoptera_data/train/bees/2405441001_b06c36fa72.jpg
# 3: ./data/Pytorch/hymenoptera_data/train/bees/2962405283_22718d9617.jpg
# 4: ./data/Pytorch/hymenoptera_data/train/bees/446296270_d9e8b93ecf.jpg
# 5: ./data/Pytorch/hymenoptera_data/train/bees/1092977343_cb42b38d62.jpg
# 6: ./data/Pytorch/hymenoptera_data/train/bees/2704348794_eb5d5178c2.jpg
# 7: ./data/Pytorch/hymenoptera_data/train/bees/2358061370_9daabbd9ac.jpg
# 8: ./data/Pytorch/hymenoptera_data/train/bees/2861002136_52c7c6f708.jpg
# 9: ./data/Pytorch/hymenoptera_data/train/bees/266644509_d30bb16a1b.jpg
# 10: ./data/Pytorch/hymenoptera_data/train/bees/2470492904_837e97800d.jpg
# 11: ./data/Pytorch/hymenoptera_data/train/bees/2053200300_8911ef438a.jpg
# 12: ./data/Pytorch/hymenoptera_data/train/bees/2601176055_8464e6aa71.jpg
# 13: ./data/Pytorch/hymenoptera_data/train/bees/473618094_8ffdcab215.jpg
# 14: ./data/Pytorch/hymenoptera_data/train/bees/150013791_969d9a968b.jpg
# 15: ./data/Pytorch/hymenoptera_data/train/bees/2486746709_c43cec0e42.jpg
# 16: ./data/Pytorch/hymenoptera_data/train/bees/452462677_7be43af8ff.jpg
# 17: ./data/Pytorch/hymenoptera_data/train/bees/2397446847_04ef3cd3e1.jpg
# 18: ./data/Pytorch/hymenoptera_data/train/bees/92663402_37f379e57a.jpg
# 19: ./data/Pytorch/hymenoptera_data/train/bees/2486729079_62df0920be.jpg
# 20: ./data/Pytorch/hymenoptera_data/train/bees/2551813042_8a070aeb2b.jpg
# 21: ./data/Pytorch/hymenoptera_data/train/bees/2792000093_e8ae0718cf.jpg
# 22: ./data/Pytorch/hymenoptera_data/train/bees/2477324698_3d4b1b1cab.jpg
# 23: ./data/Pytorch/hymenoptera_data/train/bees/2959730355_416a18c63c.jpg
# 24: ./data/Pytorch/hymenoptera_data/train/bees/774440991_63a4aa0cbe.jpg
# 25: ./data/Pytorch/hymenoptera_data/train/bees/2652877533_a564830cbf.jpg
# 26: ./data/Pytorch/hymenoptera_data/train/bees/21399619_3e61e5bb6f.jpg
# 27: ./data/Pytorch/hymenoptera_data/train/bees/586041248_3032e277a9.jpg
# 28: ./data/Pytorch/hymenoptera_data/train/bees/39672681_1302d204d1.jpg
# 29: ./data/Pytorch/hymenoptera_data/train/bees/2345177635_caf07159b3.jpg
# 30: ./data/Pytorch/hymenoptera_data/train/bees/2321139806_d73d899e66.jpg
# 31: ./data/Pytorch/hymenoptera_data/train/bees/2528444139_fa728b0f5b.jpg
# 32: ./data/Pytorch/hymenoptera_data/train/bees/3044402684_3853071a87.jpg
# 33: ./data/Pytorch/hymenoptera_data/train/bees/2683605182_9d2a0c66cf.jpg
# 34: ./data/Pytorch/hymenoptera_data/train/bees/2728759455_ce9bb8cd7a.jpg
# 35: ./data/Pytorch/hymenoptera_data/train/bees/522104315_5d3cb2758e.jpg
# 36: ./data/Pytorch/hymenoptera_data/train/bees/2493379287_4100e1dacc.jpg
# 37: ./data/Pytorch/hymenoptera_data/train/bees/478701318_bbd5e557b8.jpg
# 38: ./data/Pytorch/hymenoptera_data/train/bees/2610833167_79bf0bcae5.jpg
# 39: ./data/Pytorch/hymenoptera_data/train/bees/2710368626_cb42882dc8.jpg
# 40: ./data/Pytorch/hymenoptera_data/train/bees/1691282715_0addfdf5e8.jpg
# 41: ./data/Pytorch/hymenoptera_data/train/bees/2756397428_1d82a08807.jpg
# 42: ./data/Pytorch/hymenoptera_data/train/bees/1799726602_8580867f71.jpg
# 43: ./data/Pytorch/hymenoptera_data/train/bees/2477349551_e75c97cf4d.jpg
# 44: ./data/Pytorch/hymenoptera_data/train/bees/2031225713_50ed499635.jpg
# 45: ./data/Pytorch/hymenoptera_data/train/bees/2610838525_fe8e3cae47.jpg
# 46: ./data/Pytorch/hymenoptera_data/train/bees/3074585407_9854eb3153.jpg
# 47: ./data/Pytorch/hymenoptera_data/train/bees/2330918208_8074770c20.jpg
# 48: ./data/Pytorch/hymenoptera_data/train/bees/465133211_80e0c27f60.jpg
# 49: ./data/Pytorch/hymenoptera_data/train/bees/3079610310_ac2d0ae7bc.jpg
# 50: ./data/Pytorch/hymenoptera_data/train/bees/2495722465_879acf9d85.jpg
# 51: ./data/Pytorch/hymenoptera_data/train/bees/444532809_9e931e2279.jpg
# 52: ./data/Pytorch/hymenoptera_data/train/bees/1807583459_4fe92b3133.jpg
# 53: ./data/Pytorch/hymenoptera_data/train/bees/359928878_b3b418c728.jpg
# 54: ./data/Pytorch/hymenoptera_data/train/bees/2037437624_2d7bce461f.jpg
# 55: ./data/Pytorch/hymenoptera_data/train/bees/509247772_2db2d01374.jpg
# 56: ./data/Pytorch/hymenoptera_data/train/bees/90179376_abc234e5f4.jpg
# 57: ./data/Pytorch/hymenoptera_data/train/bees/3030772428_8578335616.jpg
# 58: ./data/Pytorch/hymenoptera_data/train/bees/873076652_eb098dab2d.jpg
# 59: ./data/Pytorch/hymenoptera_data/train/bees/17209602_fe5a5a746f.jpg
# 60: ./data/Pytorch/hymenoptera_data/train/bees/421515404_e87569fd8b.jpg
# 61: ./data/Pytorch/hymenoptera_data/train/bees/1097045929_1753d1c765.jpg
# 62: ./data/Pytorch/hymenoptera_data/train/bees/2781170484_5d61835d63.jpg
# 63: ./data/Pytorch/hymenoptera_data/train/bees/3100226504_c0d4f1e3f1.jpg
# 64: ./data/Pytorch/hymenoptera_data/train/bees/2617161745_fa3ebe85b4.jpg
# 65: ./data/Pytorch/hymenoptera_data/train/bees/2580598377_a4caecdb54.jpg
# 66: ./data/Pytorch/hymenoptera_data/train/bees/208702903_42fb4d9748.jpg
# 67: ./data/Pytorch/hymenoptera_data/train/bees/537309131_532bfa59ea.jpg
# 68: ./data/Pytorch/hymenoptera_data/train/bees/969455125_58c797ef17.jpg
# 69: ./data/Pytorch/hymenoptera_data/train/bees/365759866_b15700c59b.jpg
# 70: ./data/Pytorch/hymenoptera_data/train/bees/196430254_46bd129ae7.jpg
# 71: ./data/Pytorch/hymenoptera_data/train/bees/1232245714_f862fbe385.jpg
# 72: ./data/Pytorch/hymenoptera_data/train/bees/2445215254_51698ff797.jpg
# 73: ./data/Pytorch/hymenoptera_data/train/bees/760526046_547e8b381f.jpg
# 74: ./data/Pytorch/hymenoptera_data/train/bees/513545352_fd3e7c7c5d.jpg
# 75: ./data/Pytorch/hymenoptera_data/train/bees/2634617358_f32fd16bea.jpg
# 76: ./data/Pytorch/hymenoptera_data/train/bees/39747887_42df2855ee.jpg
# 77: ./data/Pytorch/hymenoptera_data/train/bees/354167719_22dca13752.jpg
# 78: ./data/Pytorch/hymenoptera_data/train/bees/2384149906_2cd8b0b699.jpg
# 79: ./data/Pytorch/hymenoptera_data/train/bees/2625499656_e3415e374d.jpg
# 80: ./data/Pytorch/hymenoptera_data/train/bees/2645107662_b73a8595cc.jpg
# 81: ./data/Pytorch/hymenoptera_data/train/bees/154600396_53e1252e52.jpg
# 82: ./data/Pytorch/hymenoptera_data/train/bees/279113587_b4843db199.jpg
# 83: ./data/Pytorch/hymenoptera_data/train/bees/98391118_bdb1e80cce.jpg
# 84: ./data/Pytorch/hymenoptera_data/train/bees/132511197_0b86ad0fff.jpg
# 85: ./data/Pytorch/hymenoptera_data/train/bees/2707440199_cd170bd512.jpg
# 86: ./data/Pytorch/hymenoptera_data/train/bees/342758693_c56b89b6b6.jpg
# 87: ./data/Pytorch/hymenoptera_data/train/bees/36900412_92b81831ad.jpg
# 88: ./data/Pytorch/hymenoptera_data/train/bees/2364597044_3c3e3fc391.jpg
# 89: ./data/Pytorch/hymenoptera_data/train/bees/1295655112_7813f37d21.jpg
# 90: ./data/Pytorch/hymenoptera_data/train/bees/2227611847_ec72d40403.jpg
# 91: ./data/Pytorch/hymenoptera_data/train/bees/205835650_e6f2614bee.jpg
# 92: ./data/Pytorch/hymenoptera_data/train/bees/1093831624_fb5fbe2308.jpg
# 93: ./data/Pytorch/hymenoptera_data/train/bees/129236073_0985e91c7d.jpg
# 94: ./data/Pytorch/hymenoptera_data/train/bees/198508668_97d818b6c4.jpg
# 95: ./data/Pytorch/hymenoptera_data/train/bees/1508176360_2972117c9d.jpg
# 96: ./data/Pytorch/hymenoptera_data/train/bees/457457145_5f86eb7e9c.jpg
# 97: ./data/Pytorch/hymenoptera_data/train/bees/2722592222_258d473e17.jpg
# 98: ./data/Pytorch/hymenoptera_data/train/bees/2822388965_f6dca2a275.jpg
# 99: ./data/Pytorch/hymenoptera_data/train/bees/2651621464_a2fa8722eb.jpg
# 100: ./data/Pytorch/hymenoptera_data/train/bees/132826773_dbbcb117b9.jpg
# 101: ./data/Pytorch/hymenoptera_data/train/bees/476347960_52edd72b06.jpg
# 102: ./data/Pytorch/hymenoptera_data/train/bees/3006264892_30e9cced70.jpg
# 103: ./data/Pytorch/hymenoptera_data/train/bees/760568592_45a52c847f.jpg
# 104: ./data/Pytorch/hymenoptera_data/train/bees/2452236943_255bfd9e58.jpg
# 105: ./data/Pytorch/hymenoptera_data/train/bees/472288710_2abee16fa0.jpg
# 106: ./data/Pytorch/hymenoptera_data/train/bees/2908916142_a7ac8b57a8.jpg
# 107: ./data/Pytorch/hymenoptera_data/train/bees/95238259_98470c5b10.jpg
# 108: ./data/Pytorch/hymenoptera_data/train/bees/85112639_6e860b0469.jpg
# 109: ./data/Pytorch/hymenoptera_data/train/bees/2801728106_833798c909.jpg
# 110: ./data/Pytorch/hymenoptera_data/train/bees/174142798_e5ad6d76e0.jpg
# 111: ./data/Pytorch/hymenoptera_data/train/bees/2467959963_a7831e9ff0.jpg
# 112: ./data/Pytorch/hymenoptera_data/train/bees/2538361678_9da84b77e3.jpg
# 113: ./data/Pytorch/hymenoptera_data/train/bees/196658222_3fffd79c67.jpg
# 114: ./data/Pytorch/hymenoptera_data/train/bees/29494643_e3410f0d37.jpg
# 115: ./data/Pytorch/hymenoptera_data/train/bees/16838648_415acd9e3f.jpg
# 116: ./data/Pytorch/hymenoptera_data/train/bees/3030189811_01d095b793.jpg
# 117: ./data/Pytorch/hymenoptera_data/train/bees/469333327_358ba8fe8a.jpg
# 118: ./data/Pytorch/hymenoptera_data/train/bees/452462695_40a4e5b559.jpg
# 119: ./data/Pytorch/hymenoptera_data/train/bees/3090975720_71f12e6de4.jpg
# 120: ./data/Pytorch/hymenoptera_data/train/bees/2765347790_da6cf6cb40.jpg
# 121: ./data/Pytorch/hymenoptera_data/train/ants/957233405_25c1d1187b.jpg
# 122: ./data/Pytorch/hymenoptera_data/train/ants/2288481644_83ff7e4572.jpg
# 123: ./data/Pytorch/hymenoptera_data/train/ants/67270775_e9fdf77e9d.jpg
# 124: ./data/Pytorch/hymenoptera_data/train/ants/1808777855_2a895621d7.jpg
# 125: ./data/Pytorch/hymenoptera_data/train/ants/VietnameseAntMimicSpider.jpg
# 126: ./data/Pytorch/hymenoptera_data/train/ants/swiss-army-ant.jpg
# 127: ./data/Pytorch/hymenoptera_data/train/ants/termite-vs-ant.jpg
# 128: ./data/Pytorch/hymenoptera_data/train/ants/245647475_9523dfd13e.jpg
# 129: ./data/Pytorch/hymenoptera_data/train/ants/384191229_5779cf591b.jpg
# 130: ./data/Pytorch/hymenoptera_data/train/ants/hormiga_co_por.jpg
# 131: ./data/Pytorch/hymenoptera_data/train/ants/531979952_bde12b3bc0.jpg
# 132: ./data/Pytorch/hymenoptera_data/train/ants/224655713_3956f7d39a.jpg
# 133: ./data/Pytorch/hymenoptera_data/train/ants/132478121_2a430adea2.jpg
# 134: ./data/Pytorch/hymenoptera_data/train/ants/512863248_43c8ce579b.jpg
# 135: ./data/Pytorch/hymenoptera_data/train/ants/533848102_70a85ad6dd.jpg
# 136: ./data/Pytorch/hymenoptera_data/train/ants/201558278_fe4caecc76.jpg
# 137: ./data/Pytorch/hymenoptera_data/train/ants/army-ants-red-picture.jpg
# 138: ./data/Pytorch/hymenoptera_data/train/ants/MehdiabadiAnt2_600.jpg
# 139: ./data/Pytorch/hymenoptera_data/train/ants/334167043_cbd1adaeb9.jpg
# 140: ./data/Pytorch/hymenoptera_data/train/ants/20935278_9190345f6b.jpg
# 141: ./data/Pytorch/hymenoptera_data/train/ants/540889389_48bb588b21.jpg
# 142: ./data/Pytorch/hymenoptera_data/train/ants/466430434_4000737de9.jpg
# 143: ./data/Pytorch/hymenoptera_data/train/ants/649026570_e58656104b.jpg
# 144: ./data/Pytorch/hymenoptera_data/train/ants/196057951_63bf063b92.jpg
# 145: ./data/Pytorch/hymenoptera_data/train/ants/1660097129_384bf54490.jpg
# 146: ./data/Pytorch/hymenoptera_data/train/ants/1286984635_5119e80de1.jpg
# 147: ./data/Pytorch/hymenoptera_data/train/ants/6240329_72c01e663e.jpg
# 148: ./data/Pytorch/hymenoptera_data/train/ants/Ant_1.jpg
# 149: ./data/Pytorch/hymenoptera_data/train/ants/522163566_fec115ca66.jpg
# 150: ./data/Pytorch/hymenoptera_data/train/ants/0013035.jpg
# 151: ./data/Pytorch/hymenoptera_data/train/ants/24335309_c5ea483bb8.jpg
# 152: ./data/Pytorch/hymenoptera_data/train/ants/150801171_cd86f17ed8.jpg
# 153: ./data/Pytorch/hymenoptera_data/train/ants/403746349_71384f5b58.jpg
# 154: ./data/Pytorch/hymenoptera_data/train/ants/460372577_f2f6a8c9fc.jpg
# 155: ./data/Pytorch/hymenoptera_data/train/ants/386190770_672743c9a7.jpg
# 156: ./data/Pytorch/hymenoptera_data/train/ants/886401651_f878e888cd.jpg
# 157: ./data/Pytorch/hymenoptera_data/train/ants/506249802_207cd979b4.jpg
# 158: ./data/Pytorch/hymenoptera_data/train/ants/841049277_b28e58ad05.jpg
# 159: ./data/Pytorch/hymenoptera_data/train/ants/707895295_009cf23188.jpg
# 160: ./data/Pytorch/hymenoptera_data/train/ants/Nepenthes_rafflesiana_ant.jpg
# 161: ./data/Pytorch/hymenoptera_data/train/ants/518773929_734dbc5ff4.jpg
# 162: ./data/Pytorch/hymenoptera_data/train/ants/342438950_a3da61deab.jpg
# 163: ./data/Pytorch/hymenoptera_data/train/ants/1368913450_e146e2fb6d.jpg
# 164: ./data/Pytorch/hymenoptera_data/train/ants/49375974_e28ba6f17e.jpg
# 165: ./data/Pytorch/hymenoptera_data/train/ants/822537660_caf4ba5514.jpg
# 166: ./data/Pytorch/hymenoptera_data/train/ants/36439863_0bec9f554f.jpg
# 167: ./data/Pytorch/hymenoptera_data/train/ants/175998972.jpg
# 168: ./data/Pytorch/hymenoptera_data/train/ants/382971067_0bfd33afe0.jpg
# 169: ./data/Pytorch/hymenoptera_data/train/ants/1804095607_0341701e1c.jpg
# 170: ./data/Pytorch/hymenoptera_data/train/ants/188552436_605cc9b36b.jpg
# 171: ./data/Pytorch/hymenoptera_data/train/ants/339670531_94b75ae47a.jpg
# 172: ./data/Pytorch/hymenoptera_data/train/ants/374435068_7eee412ec4.jpg
# 173: ./data/Pytorch/hymenoptera_data/train/ants/1473187633_63ccaacea6.jpg
# 174: ./data/Pytorch/hymenoptera_data/train/ants/258217966_d9d90d18d3.jpg
# 175: ./data/Pytorch/hymenoptera_data/train/ants/150801003_3390b73135.jpg
# 176: ./data/Pytorch/hymenoptera_data/train/ants/1030023514_aad5c608f9.jpg
# 177: ./data/Pytorch/hymenoptera_data/train/ants/2288450226_a6e96e8fdf.jpg
# 178: ./data/Pytorch/hymenoptera_data/train/ants/541630764_dbd285d63c.jpg
# 179: ./data/Pytorch/hymenoptera_data/train/ants/275429470_b2d7d9290b.jpg
# 180: ./data/Pytorch/hymenoptera_data/train/ants/6240338_93729615ec.jpg
# 181: ./data/Pytorch/hymenoptera_data/train/ants/424873399_47658a91fb.jpg
# 182: ./data/Pytorch/hymenoptera_data/train/ants/543417860_b14237f569.jpg
# 183: ./data/Pytorch/hymenoptera_data/train/ants/318052216_84dff3f98a.jpg
# 184: ./data/Pytorch/hymenoptera_data/train/ants/149244013_c529578289.jpg
# 185: ./data/Pytorch/hymenoptera_data/train/ants/1262877379_64fcada201.jpg
# 186: ./data/Pytorch/hymenoptera_data/train/ants/450057712_771b3bfc91.jpg
# 187: ./data/Pytorch/hymenoptera_data/train/ants/662541407_ff8db781e7.jpg
# 188: ./data/Pytorch/hymenoptera_data/train/ants/154124431_65460430f2.jpg
# 189: ./data/Pytorch/hymenoptera_data/train/ants/2019439677_2db655d361.jpg
# 190: ./data/Pytorch/hymenoptera_data/train/ants/1489674356_09d48dde0a.jpg
# 191: ./data/Pytorch/hymenoptera_data/train/ants/892108839_f1aad4ca46.jpg
# 192: ./data/Pytorch/hymenoptera_data/train/ants/522415432_2218f34bf8.jpg
# 193: ./data/Pytorch/hymenoptera_data/train/ants/178538489_bec7649292.jpg
# 194: ./data/Pytorch/hymenoptera_data/train/ants/ant photos.jpg
# 195: ./data/Pytorch/hymenoptera_data/train/ants/474806473_ca6caab245.jpg
# 196: ./data/Pytorch/hymenoptera_data/train/ants/408393566_b5b694119b.jpg
# 197: ./data/Pytorch/hymenoptera_data/train/ants/2278278459_6b99605e50.jpg
# 198: ./data/Pytorch/hymenoptera_data/train/ants/1269756697_0bce92cdab.jpg
# 199: ./data/Pytorch/hymenoptera_data/train/ants/2292213964_ca51ce4bef.jpg
# 200: ./data/Pytorch/hymenoptera_data/train/ants/226951206_d6bf946504.jpg
# 201: ./data/Pytorch/hymenoptera_data/train/ants/938946700_ca1c669085.jpg
# 202: ./data/Pytorch/hymenoptera_data/train/ants/2265824718_2c96f485da.jpg
# 203: ./data/Pytorch/hymenoptera_data/train/ants/392382602_1b7bed32fa.jpg
# 204: ./data/Pytorch/hymenoptera_data/train/ants/69639610_95e0de17aa.jpg
# 205: ./data/Pytorch/hymenoptera_data/train/ants/7759525_1363d24e88.jpg
# 206: ./data/Pytorch/hymenoptera_data/train/ants/424119020_6d57481dab.jpg
# 207: ./data/Pytorch/hymenoptera_data/train/ants/162603798_40b51f1654.jpg
# 208: ./data/Pytorch/hymenoptera_data/train/ants/28847243_e79fe052cd.jpg
# 209: ./data/Pytorch/hymenoptera_data/train/ants/998118368_6ac1d91f81.jpg
# 210: ./data/Pytorch/hymenoptera_data/train/ants/6743948_2b8c096dda.jpg
# 211: ./data/Pytorch/hymenoptera_data/train/ants/484293231_e53cfc0c89.jpg
# 212: ./data/Pytorch/hymenoptera_data/train/ants/512164029_c0a66b8498.jpg
# 213: ./data/Pytorch/hymenoptera_data/train/ants/2265825502_fff99cfd2d.jpg
# 214: ./data/Pytorch/hymenoptera_data/train/ants/459694881_ac657d3187.jpg
# 215: ./data/Pytorch/hymenoptera_data/train/ants/1099452230_d1949d3250.jpg
# 216: ./data/Pytorch/hymenoptera_data/train/ants/kurokusa.jpg
# 217: ./data/Pytorch/hymenoptera_data/train/ants/116570827_e9c126745d.jpg
# 218: ./data/Pytorch/hymenoptera_data/train/ants/167890289_dd5ba923f3.jpg
# 219: ./data/Pytorch/hymenoptera_data/train/ants/1360291657_dc248c5eea.jpg
# 220: ./data/Pytorch/hymenoptera_data/train/ants/460874319_0a45ab4d05.jpg
# 221: ./data/Pytorch/hymenoptera_data/train/ants/45472593_bfd624f8dc.jpg
# 222: ./data/Pytorch/hymenoptera_data/train/ants/207947948_3ab29d7207.jpg
# 223: ./data/Pytorch/hymenoptera_data/train/ants/535522953_308353a07c.jpg
# 224: ./data/Pytorch/hymenoptera_data/train/ants/255434217_1b2b3fe0a4.jpg
# 225: ./data/Pytorch/hymenoptera_data/train/ants/560966032_988f4d7bc4.jpg
# 226: ./data/Pytorch/hymenoptera_data/train/ants/148715752_302c84f5a4.jpg
# 227: ./data/Pytorch/hymenoptera_data/train/ants/470127037_513711fd21.jpg
# 228: ./data/Pytorch/hymenoptera_data/train/ants/9715481_b3cb4114ff.jpg
# 229: ./data/Pytorch/hymenoptera_data/train/ants/684133190_35b62c0c1d.jpg
# 230: ./data/Pytorch/hymenoptera_data/train/ants/trap-jaw-ant-insect-bg.jpg
# 231: ./data/Pytorch/hymenoptera_data/train/ants/196757565_326437f5fe.jpg
# 232: ./data/Pytorch/hymenoptera_data/train/ants/5650366_e22b7e1065.jpg
# 233: ./data/Pytorch/hymenoptera_data/train/ants/1095476100_3906d8afde.jpg
# 234: ./data/Pytorch/hymenoptera_data/train/ants/1225872729_6f0856588f.jpg
# 235: ./data/Pytorch/hymenoptera_data/train/ants/795000156_a9900a4a71.jpg
# 236: ./data/Pytorch/hymenoptera_data/train/ants/1924473702_daa9aacdbe.jpg
# 237: ./data/Pytorch/hymenoptera_data/train/ants/82852639_52b7f7f5e3.jpg
# 238: ./data/Pytorch/hymenoptera_data/train/ants/1693954099_46d4c20605.jpg
# 239: ./data/Pytorch/hymenoptera_data/train/ants/201790779_527f4c0168.jpg
# 240: ./data/Pytorch/hymenoptera_data/train/ants/475961153_b8c13fd405.jpg
# 241: ./data/Pytorch/hymenoptera_data/train/ants/506249836_717b73f540.jpg
# 242: ./data/Pytorch/hymenoptera_data/train/ants/1917341202_d00a7f9af5.jpg
# ./data/Pytorch/hymenoptera_data/val/**/*.jpg
# 0: ./data/Pytorch/hymenoptera_data/val/bees/2717418782_bd83307d9f.jpg
# 1: ./data/Pytorch/hymenoptera_data/val/bees/2173503984_9c6aaaa7e2.jpg
# 2: ./data/Pytorch/hymenoptera_data/val/bees/54736755_c057723f64.jpg
# 3: ./data/Pytorch/hymenoptera_data/val/bees/2103637821_8d26ee6b90.jpg
# 4: ./data/Pytorch/hymenoptera_data/val/bees/603711658_4c8cd2201e.jpg
# 5: ./data/Pytorch/hymenoptera_data/val/bees/238161922_55fa9a76ae.jpg
# 6: ./data/Pytorch/hymenoptera_data/val/bees/2457841282_7867f16639.jpg
# 7: ./data/Pytorch/hymenoptera_data/val/bees/6a00d8341c630a53ef00e553d0beb18834-800wi.jpg
# 8: ./data/Pytorch/hymenoptera_data/val/bees/177677657_a38c97e572.jpg
# 9: ./data/Pytorch/hymenoptera_data/val/bees/348291597_ee836fbb1a.jpg
# 10: ./data/Pytorch/hymenoptera_data/val/bees/152789693_220b003452.jpg
# 11: ./data/Pytorch/hymenoptera_data/val/bees/2782079948_8d4e94a826.jpg
# 12: ./data/Pytorch/hymenoptera_data/val/bees/576452297_897023f002.jpg
# 13: ./data/Pytorch/hymenoptera_data/val/bees/1181173278_23c36fac71.jpg
# 14: ./data/Pytorch/hymenoptera_data/val/bees/3077452620_548c79fda0.jpg
# 15: ./data/Pytorch/hymenoptera_data/val/bees/586474709_ae436da045.jpg
# 16: ./data/Pytorch/hymenoptera_data/val/bees/26589803_5ba7000313.jpg
# 17: ./data/Pytorch/hymenoptera_data/val/bees/2478216347_535c8fe6d7.jpg
# 18: ./data/Pytorch/hymenoptera_data/val/bees/2668391343_45e272cd07.jpg
# 19: ./data/Pytorch/hymenoptera_data/val/bees/540976476_844950623f.jpg
# 20: ./data/Pytorch/hymenoptera_data/val/bees/144098310_a4176fd54d.jpg
# 21: ./data/Pytorch/hymenoptera_data/val/bees/1486120850_490388f84b.jpg
# 22: ./data/Pytorch/hymenoptera_data/val/bees/2670536155_c170f49cd0.jpg
# 23: ./data/Pytorch/hymenoptera_data/val/bees/1519368889_4270261ee3.jpg
# 24: ./data/Pytorch/hymenoptera_data/val/bees/2506114833_90a41c5267.jpg
# 25: ./data/Pytorch/hymenoptera_data/val/bees/2438480600_40a1249879.jpg
# 26: ./data/Pytorch/hymenoptera_data/val/bees/187130242_4593a4c610.jpg
# 27: ./data/Pytorch/hymenoptera_data/val/bees/224841383_d050f5f510.jpg
# 28: ./data/Pytorch/hymenoptera_data/val/bees/59798110_2b6a3c8031.jpg
# 29: ./data/Pytorch/hymenoptera_data/val/bees/2883093452_7e3a1eb53f.jpg
# 30: ./data/Pytorch/hymenoptera_data/val/bees/2321144482_f3785ba7b2.jpg
# 31: ./data/Pytorch/hymenoptera_data/val/bees/abeja.jpg
# 32: ./data/Pytorch/hymenoptera_data/val/bees/203868383_0fcbb48278.jpg
# 33: ./data/Pytorch/hymenoptera_data/val/bees/44105569_16720a960c.jpg
# 34: ./data/Pytorch/hymenoptera_data/val/bees/272986700_d4d4bf8c4b.jpg
# 35: ./data/Pytorch/hymenoptera_data/val/bees/464594019_1b24a28bb1.jpg
# 36: ./data/Pytorch/hymenoptera_data/val/bees/485743562_d8cc6b8f73.jpg
# 37: ./data/Pytorch/hymenoptera_data/val/bees/2815838190_0a9889d995.jpg
# 38: ./data/Pytorch/hymenoptera_data/val/bees/603709866_a97c7cfc72.jpg
# 39: ./data/Pytorch/hymenoptera_data/val/bees/2086294791_6f3789d8a6.jpg
# 40: ./data/Pytorch/hymenoptera_data/val/bees/1328423762_f7a88a8451.jpg
# 41: ./data/Pytorch/hymenoptera_data/val/bees/416144384_961c326481.jpg
# 42: ./data/Pytorch/hymenoptera_data/val/bees/2709775832_85b4b50a57.jpg
# 43: ./data/Pytorch/hymenoptera_data/val/bees/1297972485_33266a18d9.jpg
# 44: ./data/Pytorch/hymenoptera_data/val/bees/2415414155_1916f03b42.jpg
# 45: ./data/Pytorch/hymenoptera_data/val/bees/149973093_da3c446268.jpg
# 46: ./data/Pytorch/hymenoptera_data/val/bees/2741763055_9a7bb00802.jpg
# 47: ./data/Pytorch/hymenoptera_data/val/bees/936182217_c4caa5222d.jpg
# 48: ./data/Pytorch/hymenoptera_data/val/bees/1799729694_0c40101071.jpg
# 49: ./data/Pytorch/hymenoptera_data/val/bees/2841437312_789699c740.jpg
# 50: ./data/Pytorch/hymenoptera_data/val/bees/2509402554_31821cb0b6.jpg
# 51: ./data/Pytorch/hymenoptera_data/val/bees/372228424_16da1f8884.jpg
# 52: ./data/Pytorch/hymenoptera_data/val/bees/456097971_860949c4fc.jpg
# 53: ./data/Pytorch/hymenoptera_data/val/bees/2525379273_dcb26a516d.jpg
# 54: ./data/Pytorch/hymenoptera_data/val/bees/2809496124_5f25b5946a.jpg
# 55: ./data/Pytorch/hymenoptera_data/val/bees/2060668999_e11edb10d0.jpg
# 56: ./data/Pytorch/hymenoptera_data/val/bees/1355974687_1341c1face.jpg
# 57: ./data/Pytorch/hymenoptera_data/val/bees/2751836205_6f7b5eff30.jpg
# 58: ./data/Pytorch/hymenoptera_data/val/bees/2702408468_d9ed795f4f.jpg
# 59: ./data/Pytorch/hymenoptera_data/val/bees/2444778727_4b781ac424.jpg
# 60: ./data/Pytorch/hymenoptera_data/val/bees/1032546534_06907fe3b3.jpg
# 61: ./data/Pytorch/hymenoptera_data/val/bees/215512424_687e1e0821.jpg
# 62: ./data/Pytorch/hymenoptera_data/val/bees/2745389517_250a397f31.jpg
# 63: ./data/Pytorch/hymenoptera_data/val/bees/590318879_68cf112861.jpg
# 64: ./data/Pytorch/hymenoptera_data/val/bees/2685605303_9eed79d59d.jpg
# 65: ./data/Pytorch/hymenoptera_data/val/bees/296565463_d07a7bed96.jpg
# 66: ./data/Pytorch/hymenoptera_data/val/bees/350436573_41f4ecb6c8.jpg
# 67: ./data/Pytorch/hymenoptera_data/val/bees/290082189_f66cb80bfc.jpg
# 68: ./data/Pytorch/hymenoptera_data/val/bees/10870992_eebeeb3a12.jpg
# 69: ./data/Pytorch/hymenoptera_data/val/bees/151603988_2c6f7d14c7.jpg
# 70: ./data/Pytorch/hymenoptera_data/val/bees/759745145_e8bc776ec8.jpg
# 71: ./data/Pytorch/hymenoptera_data/val/bees/181171681_c5a1a82ded.jpg
# 72: ./data/Pytorch/hymenoptera_data/val/bees/2104135106_a65eede1de.jpg
# 73: ./data/Pytorch/hymenoptera_data/val/bees/2470492902_3572c90f75.jpg
# 74: ./data/Pytorch/hymenoptera_data/val/bees/353266603_d3eac7e9a0.jpg
# 75: ./data/Pytorch/hymenoptera_data/val/bees/57459255_752774f1b2.jpg
# 76: ./data/Pytorch/hymenoptera_data/val/bees/2501530886_e20952b97d.jpg
# 77: ./data/Pytorch/hymenoptera_data/val/bees/65038344_52a45d090d.jpg
# 78: ./data/Pytorch/hymenoptera_data/val/bees/220376539_20567395d8.jpg
# 79: ./data/Pytorch/hymenoptera_data/val/bees/151594775_ee7dc17b60.jpg
# 80: ./data/Pytorch/hymenoptera_data/val/bees/400262091_701c00031c.jpg
# 81: ./data/Pytorch/hymenoptera_data/val/bees/72100438_73de9f17af.jpg
# 82: ./data/Pytorch/hymenoptera_data/val/bees/2407809945_fb525ef54d.jpg
# 83: ./data/Pytorch/hymenoptera_data/val/ants/459442412_412fecf3fe.jpg
# 84: ./data/Pytorch/hymenoptera_data/val/ants/800px-Meat_eater_ant_qeen_excavating_hole.jpg
# 85: ./data/Pytorch/hymenoptera_data/val/ants/892676922_4ab37dce07.jpg
# 86: ./data/Pytorch/hymenoptera_data/val/ants/F.pergan.28(f).jpg
# 87: ./data/Pytorch/hymenoptera_data/val/ants/1247887232_edcb61246c.jpg
# 88: ./data/Pytorch/hymenoptera_data/val/ants/181942028_961261ef48.jpg
# 89: ./data/Pytorch/hymenoptera_data/val/ants/1073564163_225a64f170.jpg
# 90: ./data/Pytorch/hymenoptera_data/val/ants/2238242353_52c82441df.jpg
# 91: ./data/Pytorch/hymenoptera_data/val/ants/205398178_c395c5e460.jpg
# 92: ./data/Pytorch/hymenoptera_data/val/ants/263615709_cfb28f6b8e.jpg
# 93: ./data/Pytorch/hymenoptera_data/val/ants/94999827_36895faade.jpg
# 94: ./data/Pytorch/hymenoptera_data/val/ants/436944325_d4925a38c7.jpg
# 95: ./data/Pytorch/hymenoptera_data/val/ants/161076144_124db762d6.jpg
# 96: ./data/Pytorch/hymenoptera_data/val/ants/147542264_79506478c2.jpg
# 97: ./data/Pytorch/hymenoptera_data/val/ants/239161491_86ac23b0a3.jpg
# 98: ./data/Pytorch/hymenoptera_data/val/ants/1053149811_f62a3410d3.jpg
# 99: ./data/Pytorch/hymenoptera_data/val/ants/1124525276_816a07c17f.jpg
# 100: ./data/Pytorch/hymenoptera_data/val/ants/2211974567_ee4606b493.jpg
# 101: ./data/Pytorch/hymenoptera_data/val/ants/2191997003_379df31291.jpg
# 102: ./data/Pytorch/hymenoptera_data/val/ants/183260961_64ab754c97.jpg
# 103: ./data/Pytorch/hymenoptera_data/val/ants/562589509_7e55469b97.jpg
# 104: ./data/Pytorch/hymenoptera_data/val/ants/ants-devouring-remains-of-large-dead-insect-on-red-tile-in-Stellenbosch-South-Africa-closeup-1-DHD.jpg
# 105: ./data/Pytorch/hymenoptera_data/val/ants/751649788_78dd7d16ce.jpg
# 106: ./data/Pytorch/hymenoptera_data/val/ants/157401988_d0564a9d02.jpg
# 107: ./data/Pytorch/hymenoptera_data/val/ants/2039585088_c6f47c592e.jpg
# 108: ./data/Pytorch/hymenoptera_data/val/ants/153320619_2aeb5fa0ee.jpg
# 109: ./data/Pytorch/hymenoptera_data/val/ants/649407494_9b6bc4949f.jpg
# 110: ./data/Pytorch/hymenoptera_data/val/ants/470127071_8b8ee2bd74.jpg
# 111: ./data/Pytorch/hymenoptera_data/val/ants/Hormiga.jpg
# 112: ./data/Pytorch/hymenoptera_data/val/ants/502717153_3e4865621a.jpg
# 113: ./data/Pytorch/hymenoptera_data/val/ants/573151833_ebbc274b77.jpg
# 114: ./data/Pytorch/hymenoptera_data/val/ants/57264437_a19006872f.jpg
# 115: ./data/Pytorch/hymenoptera_data/val/ants/540543309_ddbb193ee5.jpg
# 116: ./data/Pytorch/hymenoptera_data/val/ants/2255445811_dabcdf7258.jpg
# 117: ./data/Pytorch/hymenoptera_data/val/ants/445356866_6cb3289067.jpg
# 118: ./data/Pytorch/hymenoptera_data/val/ants/8124241_36b290d372.jpg
# 119: ./data/Pytorch/hymenoptera_data/val/ants/Ant-1818.jpg
# 120: ./data/Pytorch/hymenoptera_data/val/ants/208072188_f293096296.jpg
# 121: ./data/Pytorch/hymenoptera_data/val/ants/2104709400_8831b4fc6f.jpg
# 122: ./data/Pytorch/hymenoptera_data/val/ants/159515240_d5981e20d1.jpg
# 123: ./data/Pytorch/hymenoptera_data/val/ants/518746016_bcc28f8b5b.jpg
# 124: ./data/Pytorch/hymenoptera_data/val/ants/10308379_1b6c72e180.jpg
# 125: ./data/Pytorch/hymenoptera_data/val/ants/172772109_d0a8e15fb0.jpg
# 126: ./data/Pytorch/hymenoptera_data/val/ants/1440002809_b268d9a66a.jpg
# 127: ./data/Pytorch/hymenoptera_data/val/ants/1358854066_5ad8015f7f.jpg
# 128: ./data/Pytorch/hymenoptera_data/val/ants/412436937_4c2378efc2.jpg
# 129: ./data/Pytorch/hymenoptera_data/val/ants/119785936_dd428e40c3.jpg
# 130: ./data/Pytorch/hymenoptera_data/val/ants/1337725712_2eb53cd742.jpg
# 131: ./data/Pytorch/hymenoptera_data/val/ants/152286280_411648ec27.jpg
# 132: ./data/Pytorch/hymenoptera_data/val/ants/161292361_c16e0bf57a.jpg
# 133: ./data/Pytorch/hymenoptera_data/val/ants/477437164_bc3e6e594a.jpg
# 134: ./data/Pytorch/hymenoptera_data/val/ants/768870506_8f115d3d37.jpg
# 135: ./data/Pytorch/hymenoptera_data/val/ants/488272201_c5aa281348.jpg
# 136: ./data/Pytorch/hymenoptera_data/val/ants/2219621907_47bc7cc6b0.jpg
# 137: ./data/Pytorch/hymenoptera_data/val/ants/854534770_31f6156383.jpg
# 138: ./data/Pytorch/hymenoptera_data/val/ants/209615353_eeb38ba204.jpg
# 139: ./data/Pytorch/hymenoptera_data/val/ants/35558229_1fa4608a7a.jpg
# 140: ./data/Pytorch/hymenoptera_data/val/ants/11381045_b352a47d8c.jpg
# 141: ./data/Pytorch/hymenoptera_data/val/ants/212100470_b485e7b7b9.jpg
# 142: ./data/Pytorch/hymenoptera_data/val/ants/1743840368_b5ccda82b7.jpg
# 143: ./data/Pytorch/hymenoptera_data/val/ants/170652283_ecdaff5d1a.jpg
# 144: ./data/Pytorch/hymenoptera_data/val/ants/17081114_79b9a27724.jpg
# 145: ./data/Pytorch/hymenoptera_data/val/ants/8398478_50ef10c47a.jpg
# 146: ./data/Pytorch/hymenoptera_data/val/ants/1262751255_c56c042b7b.jpg
# 147: ./data/Pytorch/hymenoptera_data/val/ants/308196310_1db5ffa01b.jpg
# 148: ./data/Pytorch/hymenoptera_data/val/ants/desert_ant.jpg
# 149: ./data/Pytorch/hymenoptera_data/val/ants/153783656_85f9c3ac70.jpg
# 150: ./data/Pytorch/hymenoptera_data/val/ants/1119630822_cd325ea21a.jpg
# 151: ./data/Pytorch/hymenoptera_data/val/ants/319494379_648fb5a1c6.jpg
# 152: ./data/Pytorch/hymenoptera_data/val/ants/2127908701_d49dc83c97.jpg
# torch.Size([3, 224, 224])
# a/tr
# Training Data:
# train_0 :a/tr
# train_1 :a/tr
# train_2 :a/tr
# train_3 :a/tr
# train_4 :a/tr
# train_5 :a/tr
# train_6 :a/tr
# train_7 :a/tr
# train_8 :a/tr
# train_9 :a/tr
# train_10 :a/tr
# train_11 :a/tr
# train_12 :a/tr
# train_13 :a/tr
# train_14 :a/tr
# train_15 :a/tr
# train_16 :a/tr
# train_17 :a/tr
# train_18 :a/tr
# train_19 :a/tr
# train_20 :a/tr
# train_21 :a/tr
# train_22 :a/tr
# train_23 :a/tr
# train_24 :a/tr
# train_25 :a/tr
# train_26 :a/tr
# train_27 :a/tr
# train_28 :a/tr
# train_29 :a/tr
# train_30 :a/tr
# train_31 :a/tr
# train_32 :a/tr
# train_33 :a/tr
# train_34 :a/tr
# train_35 :a/tr
# train_36 :a/tr
# train_37 :a/tr
# train_38 :a/tr
# train_39 :a/tr
# train_40 :a/tr
# train_41 :a/tr
# train_42 :a/tr
# train_43 :a/tr
# train_44 :a/tr
# train_45 :a/tr
# train_46 :a/tr
# train_47 :a/tr
# train_48 :a/tr
# train_49 :a/tr
# train_50 :a/tr
# train_51 :a/tr
# train_52 :a/tr
# train_53 :a/tr
# train_54 :a/tr
# train_55 :a/tr
# train_56 :a/tr
# train_57 :a/tr
# train_58 :a/tr
# train_59 :a/tr
# train_60 :a/tr
# train_61 :a/tr
# train_62 :a/tr
# train_63 :a/tr
# train_64 :a/tr
# train_65 :a/tr
# train_66 :a/tr
# train_67 :a/tr
# train_68 :a/tr
# train_69 :a/tr
# train_70 :a/tr
# train_71 :a/tr
# train_72 :a/tr
# train_73 :a/tr
# train_74 :a/tr
# train_75 :a/tr
# train_76 :a/tr
# train_77 :a/tr
# train_78 :a/tr
# train_79 :a/tr
# train_80 :a/tr
# train_81 :a/tr
# train_82 :a/tr
# train_83 :a/tr
# train_84 :a/tr
# train_85 :a/tr
# train_86 :a/tr
# train_87 :a/tr
# train_88 :a/tr
# train_89 :a/tr
# train_90 :a/tr
# train_91 :a/tr
# train_92 :a/tr
# train_93 :a/tr
# train_94 :a/tr
# train_95 :a/tr
# train_96 :a/tr
# train_97 :a/tr
# train_98 :a/tr
# train_99 :a/tr
# train_100 :a/tr
# train_101 :a/tr
# train_102 :a/tr
# train_103 :a/tr
# train_104 :a/tr
# train_105 :a/tr
# train_106 :a/tr
# train_107 :a/tr
# train_108 :a/tr
# train_109 :a/tr
# train_110 :a/tr
# train_111 :a/tr
# train_112 :a/tr
# train_113 :a/tr
# train_114 :a/tr
# train_115 :a/tr
# train_116 :a/tr
# train_117 :a/tr
# train_118 :a/tr
# train_119 :a/tr
# train_120 :a/tr
# train_121 :a/tr
# train_122 :a/tr
# train_123 :a/tr
# train_124 :a/tr
# train_125 :a/tr
# train_126 :a/tr
# train_127 :a/tr
# train_128 :a/tr
# train_129 :a/tr
# train_130 :a/tr
# train_131 :a/tr
# train_132 :a/tr
# train_133 :a/tr
# train_134 :a/tr
# train_135 :a/tr
# train_136 :a/tr
# train_137 :a/tr
# train_138 :a/tr
# train_139 :a/tr
# train_140 :a/tr
# train_141 :a/tr
# train_142 :a/tr
# train_143 :a/tr
# train_144 :a/tr
# train_145 :a/tr
# train_146 :a/tr
# train_147 :a/tr
# train_148 :a/tr
# train_149 :a/tr
# train_150 :a/tr
# train_151 :a/tr
# train_152 :a/tr
# train_153 :a/tr
# train_154 :a/tr
# train_155 :a/tr
# train_156 :a/tr
# train_157 :a/tr
# train_158 :a/tr
# train_159 :a/tr
# train_160 :a/tr
# train_161 :a/tr
# train_162 :a/tr
# train_163 :a/tr
# train_164 :a/tr
# train_165 :a/tr
# train_166 :a/tr
# train_167 :a/tr
# train_168 :a/tr
# train_169 :a/tr
# train_170 :a/tr
# train_171 :a/tr
# train_172 :a/tr
# train_173 :a/tr
# train_174 :a/tr
# train_175 :a/tr
# train_176 :a/tr
# train_177 :a/tr
# train_178 :a/tr
# train_179 :a/tr
# train_180 :a/tr
# train_181 :a/tr
# train_182 :a/tr
# train_183 :a/tr
# train_184 :a/tr
# train_185 :a/tr
# train_186 :a/tr
# train_187 :a/tr
# train_188 :a/tr
# train_189 :a/tr
# train_190 :a/tr
# train_191 :a/tr
# train_192 :a/tr
# train_193 :a/tr
# train_194 :a/tr
# train_195 :a/tr
# train_196 :a/tr
# train_197 :a/tr
# train_198 :a/tr
# train_199 :a/tr
# train_200 :a/tr
# train_201 :a/tr
# train_202 :a/tr
# train_203 :a/tr
# train_204 :a/tr
# train_205 :a/tr
# train_206 :a/tr
# train_207 :a/tr
# train_208 :a/tr
# train_209 :a/tr
# train_210 :a/tr
# train_211 :a/tr
# train_212 :a/tr
# train_213 :a/tr
# train_214 :a/tr
# train_215 :a/tr
# train_216 :a/tr
# train_217 :a/tr
# train_218 :a/tr
# train_219 :a/tr
# train_220 :a/tr
# train_221 :a/tr
# train_222 :a/tr
# train_223 :a/tr
# train_224 :a/tr
# train_225 :a/tr
# train_226 :a/tr
# train_227 :a/tr
# train_228 :a/tr
# train_229 :a/tr
# train_230 :a/tr
# train_231 :a/tr
# train_232 :a/tr
# train_233 :a/tr
# train_234 :a/tr
# train_235 :a/tr
# train_236 :a/tr
# train_237 :a/tr
# train_238 :a/tr
# train_239 :a/tr
# train_240 :a/tr
# train_241 :a/tr
# train_242 :a/tr
# torch.Size([32, 3, 224, 224])
# ('a/tr', 'a/tr', 'a/tr', 'a/tr', 'a/tr', 'a/tr', 'a/tr', 'a/tr', 'a/tr', 'a/tr', 'a/tr', 'a/tr', 'a/tr', 'a/tr', 'a/tr', 'a/tr', 'a/tr', 'a/tr', 'a/tr', 'a/tr', 'a/tr', 'a/tr', 'a/tr', 'a/tr', 'a/tr', 'a/tr', 'a/tr', 'a/tr', 'a/tr', 'a/tr', 'a/tr', 'a/tr')

# %% [markdown]
# ### ネットワークモデル

# %%
# ネットワークモデル作成
use_pretained = True
net = models.vgg16(pretrained=use_pretained) # 学習済みモデルVGG-16をロード
net.classifier[6] = nn.Linear(in_features=4096, out_features=2) # 出力層の出力ユニットをアリとハチの2つに付け替える
net.train() # 訓練モードに設定
print('ネットワーク設定完了: 学習済み重みを読み込み、訓練モードに設定しました。')

 # 損失関数の設定
criterion = nn.CrossEntropyLoss()
# Out:
# ネットワーク設定完了: 学習済み重みを読み込み、訓練モードに設定しました。

# %% [markdown]
# ### ファインチューニング

# %%
# 異なる学習率毎にlistを作成
params_to_update_1 = []
params_to_update_2 = []
params_to_update_3 = []

# %%
# 学習させる層のパラメータ名を指定
update_param_names_1 = ["features"]
update_param_names_2 = ["classifier.0.weight", "classifier.0.bias", "classifier.3.weight", "classifier.3.bias"]
update_param_names_3 = ["classifier.6.weight", "classifier.6.bias"]

print(update_param_names_1)
print(update_param_names_1[0])
# Out:
# ['features']
# features

# %%
# パラメータ毎に各リストに格納する
for name, param, in net.named_parameters():
    if update_param_names_1[0] in name:
        param.requires_grad = True
        params_to_update_1.append(param)
        print("params_to_update_1に格納: ", name)
    elif name in update_param_names_2:
        param.requires_grad = True
        params_to_update_2.append(param)
        print("params_to_update_2に格納:", name)
    elif name in update_param_names_3:
        param.requires_grad = True
        params_to_update_3.append(param)
        print("params_to_update_3に格納:", name)
    else:
        param.requires_grad = False
        print("勾配計算なし。学習しない:", name)
# Out:
# params_to_update_1に格納:  features.0.weight
# params_to_update_1に格納:  features.0.bias
# params_to_update_1に格納:  features.2.weight
# params_to_update_1に格納:  features.2.bias
# params_to_update_1に格納:  features.5.weight
# params_to_update_1に格納:  features.5.bias
# params_to_update_1に格納:  features.7.weight
# params_to_update_1に格納:  features.7.bias
# params_to_update_1に格納:  features.10.weight
# params_to_update_1に格納:  features.10.bias
# params_to_update_1に格納:  features.12.weight
# params_to_update_1に格納:  features.12.bias
# params_to_update_1に格納:  features.14.weight
# params_to_update_1に格納:  features.14.bias
# params_to_update_1に格納:  features.17.weight
# params_to_update_1に格納:  features.17.bias
# params_to_update_1に格納:  features.19.weight
# params_to_update_1に格納:  features.19.bias
# params_to_update_1に格納:  features.21.weight
# params_to_update_1に格納:  features.21.bias
# params_to_update_1に格納:  features.24.weight
# params_to_update_1に格納:  features.24.bias
# params_to_update_1に格納:  features.26.weight
# params_to_update_1に格納:  features.26.bias
# params_to_update_1に格納:  features.28.weight
# params_to_update_1に格納:  features.28.bias
# params_to_update_2に格納: classifier.0.weight
# params_to_update_2に格納: classifier.0.bias
# params_to_update_2に格納: classifier.3.weight
# params_to_update_2に格納: classifier.3.bias
# params_to_update_3に格納: classifier.6.weight
# params_to_update_3に格納: classifier.6.bias

# %%
# 最適化手法の設定
optimizer = optim.SGD([
    {'params': params_to_update_1, 'lr': 1e-4},
    {'params': params_to_update_2, 'lr': 5e-4},
    {'params': params_to_update_3, 'lr': 1e-3}
], momentum=0.9)

# %%
# 初期設定
# GPUが使えるか確認
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("使用デバイス: ", device)

# ネットワークをGPUへ転送
net.to(device)

# ネットワークがある程度固定であれば、高速化される
torch.backends.cudnn.benchmark = True

# エポック
num_epochs = 2
# Out:
# 使用デバイス:  cpu

# %%
# epochのループ
for epoch in range(num_epochs):
    print('Epoch {}/{}'.format(epoch+1, num_epochs))
    print('--------')

    # epochごとの学習と検証ループ
    for phase in ['train', 'val']:
        if phase == 'train':
            net.train() # 訓練モードのモデル
        else:
            net.eval()  # 検証モードのモデル

        epoch_loss = 0.0   # epochの損失和
        epoch_corrects = 0 # epochの正解数 

        # 未学習時の検証性能を確かめるため、epoch=0の訓練では未学習のモデルを使用する
        if (epoch == 0) and (phase == 'train'):
            continue

        # データローダからミニバッチを取り出すループ
        for inputs, labels in tqdm(dataloaders_dict[phase]):

            # GPUが使えるならGPUにデータを転送
            inputs = inputs.to(device)
            labels = labels.to(device)

            # optimzerを初期化
            optimizer.zero_grad()

            # forward計算
            with torch.set_grad_enabled(phase == 'train'):
                outputs = net(inputs)              # 出力
                loss = criterion(outputs, labels)  # 誤差
                _, preds = torch.max(outputs, 1)   # 予測ラベル

                # 訓練時はbackpropagation
                if phase == 'train':
                    loss.backward()
                    optimizer.step()

                # イテレーションの計算結果
                # lossの合計を更新
                epoch_loss += loss.item() * inputs.size(0) # 平均loss * バッチ数
                # 正解数の合計を更新
                epoch_corrects += torch.sum(preds == labels.data)

        # epochごとのlossと正解率を表示
        epoch_loss = epoch_loss / len(dataloaders_dict[phase].dataset)
        epoch_acc = epoch_corrects.double() / len(dataloaders_dict[phase].dataset)

        print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_acc))
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# Epoch 1/2
# --------
#   0%|          | 0/5 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-f470d41f8ea4> in <module>
#      23             # GPUが使えるならGPUにデータを転送
#      24             inputs = inputs.to(device)
# ---> 25             labels = labels.to(device)
#      26
#      27             # optimzerを初期化
#
# AttributeError: 'tuple' object has no attribute 'to'

# %% [markdown]
# ### モデルの保存

# %%
"""モデルの保存"""
save_path = './data/Pytorch/finetuning_weight/weights_fine_tuning.pth'
torch.save(net.state_dict(), save_path)

# %% [markdown]
# ### モデルの読み込み

# %%
"""モデルの読み込み"""
load_path = "./data/Pytorch/finetuning_weight/weights_fine_tuning.pth"
load_weights = torch.load(load_path)
net.load_state_dict(load_weights)
# Out:
# <All keys matched successfully>

# %% [markdown]
# ### GPU -> CPU

# %%
# GPU上で保存された重みをCPU上でロードする場合
load_weights = torch.load(load_path, map_location={'cuda:0': 'cpu'})
net.load_state_dict(load_weights)
# Out:
# <All keys matched successfully>
